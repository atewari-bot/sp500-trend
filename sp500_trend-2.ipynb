# %% [markdown]
# # Self-Study Colab Activity 1.1: Creating Hist, Scatter, Line, and Bar Plots

# %% [markdown]
# ### In this exercise, generate some basic charts using Pandas.

# %%
pip install matplotlib
# Out:
# WARNING: The directory '/Users/atewari/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /usr/local/Cellar/jupyterlab/4.2.5_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import data from pandas
import pandas as pd
import os

#Make directory called plots
os.makedirs("plots", exist_ok=True)

#create the DataFrame utilizing Pandas
data = pd.read_csv("sp500_trends.csv")

#generate all info for this dataset
data.info()

#Remove the last line of NAN
data = data.iloc[:-1 , :]

#Ignore any warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2128 entries, 0 to 2127
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      2128 non-null   int64
#  1   Date            2128 non-null   object
#  2   sp500_increase  2128 non-null   int64
#  3   sp500_changep   2128 non-null   float64
#  4   ADBE_increase   2128 non-null   int64
#  5   ADBE_changep    2128 non-null   float64
#  6   INTC_increase   2128 non-null   int64
#  7   INTC_changep    2128 non-null   float64
#  8   MSFT_increase   2128 non-null   int64
#  9   MSFT_changep    2128 non-null   float64
#  10  AMD_increase    2128 non-null   int64
#  11  AMD_changep     2128 non-null   float64
#  12  NVDA_increase   2128 non-null   int64
#  13  NVDA_changep    2128 non-null   float64
#  14  DIS_increase    2128 non-null   int64
#  15  DIS_changep     2128 non-null   float64
#  16  NFLX_increase   2128 non-null   int64
# ...

# %% [markdown]
# ###  Part One: In this exercise, generate a basic histogram.

# %%
data
# Out:
#       Unnamed: 0        Date  sp500_increase  sp500_changep  ADBE_increase  \
# 0              0  2021-04-19               0      -0.252251              0
# 1              1  2021-04-16               1       0.002399              1
# 2              2  2021-04-15               1       0.514817              1
# 3              3  2021-04-14               0      -0.334272              0
# 4              4  2021-04-13               1       0.323181              1
# ...          ...         ...             ...            ...            ...
# 2122        2122  2012-05-25               0      -0.286828              0
# 2123        2123  2012-05-24               0      -0.075402              0
# 2124        2124  2012-05-23               1       0.777146              1
# 2125        2125  2012-05-22               0      -0.083139              1
# 2126        2126  2012-05-21               1       1.390594              1
#
# ...

# %%
#Please generate a basic histogram and save the histogram as a png file
# Hint: use pandas histogram function.

#data.plot(kind='hist', figsize=(10,10))
#df = data[x='sp500_increase', y=['MSFT_increase', 'DIS_increase', 'NFLX_increase', 'TSLA_increase']]
# Scatter example
# df.plot(x='sp500_increase', y='MSFT_increase',kind='scatter',figsize=(10, 10))
import matplotlib.pyplot as plt
from google.colab import files
col = [
    'sp500_changep','MSFT_changep','DIS_changep','NFLX_changep','TSLA_changep','ADBE_changep','META_changep',
    'INTC_changep','AMD_changep','NVDA_changep'
]
col3 = [
    'MSFT_changep','DIS_changep','NFLX_changep','TSLA_changep','ADBE_changep','META_changep','INTC_changep','AMD_changep',
    'NVDA_changep'
]

col4 = [
    'sp500_increase','MSFT_increase','DIS_increase','NFLX_increase','TSLA_increase','ADBE_increase','META_increase',
    'INTC_increase','AMD_increase','NVDA_increase'
]
col5 = [
    'MSFT_increase','DIS_increase','NFLX_increase','TSLA_increase','ADBE_increase','META_increase','INTC_increase','AMD_increase',
    'NVDA_increase'
]
df = data[col]
df1 = data['sp500_changep']
df2 = data['sp500_increase']
df3 = data[col3]
df4 = data[col4]
df5 = data[col5]
df.plot(kind='hist', stacked=True, figsize=(10,10), alpha=0.6, bins=20, subplots=True)
plt.xlabel('EP Change')
plt.savefig('histogram_subplots-sp500_vs_tech_stocks.png')  # Save the file
plt.show()
files.download('histogram_subplots-sp500_vs_tech_stocks.png')


# df1.plot(kind='hist', stacked=True, figsize=(5,5), alpha=0.6, bins=20)
# plt.xlabel('EP Change')
# plt.savefig('stacked_histogram_graph_sp500.png')  # Save the file
# plt.show()
# files.download('stacked_histogram_graph_sp500.png')
# df3.plot(kind='hist', stacked=True, figsize=(10,10), alpha=0.6, bins=20)
# plt.xlabel('EP Change')
# plt.savefig('stacked_histogram_graph_tech_stock.png')  # Save the file
# plt.show()
# files.download('stacked_histogram_graph_tech_stock.png')

# df2.plot(kind='kde', stacked=True, figsize=(10,10), alpha=0.6)
# plt.xlabel('Stock Price Change')
# plt.savefig('density_graph_sp500.png')  # Save the file
# plt.show()
# files.download('density_graph_sp500.png')

# df5.plot(kind='kde', stacked=True, figsize=(10,10), alpha=0.6)
# plt.xlabel('Stock Price Change')
# plt.savefig('density_graph_tech_stocks.png')  # Save the file
# plt.show()
# files.download('density_graph_tech_stocks.png')

# %% [markdown]
# ###  Part Two: In this exercise, generate a basic scatter plot.

# %%
#Please generate a basic scatter plot utilizing Age as the x axis and Salary as the y axis
# Hint: use pandas scatter function to generate the chart.

scat =

print(scat)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ###  Part Three: In this exercise, generate a basic lineplot.

# %%
# Please generate a basic line plot by name as the x axis and salary as the y axis
#for the "Golden State Warriors" using the nba data set.
#Note a new dataframe called teamdata has been created for you that will be used during the rest of this



teamdata = data.filter(items=['Team', 'Name', 'Salary'])
teamdata = teamdata.loc[data.Team == 'Golden State Warriors', 'Name':'Salary']
teamdata.set_index('Name')


lines =


# ANSWER CHECK
print(lines)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ###  Part Four: In this exercise, generate a basic bar chart.

# %%
# Please generate a basic bar plot by name as the x axis and salary as the y axis of the teamdata dataframe.


bar =



print(bar)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
